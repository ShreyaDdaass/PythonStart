# %% [markdown]
# Digit

# %%
number = int (input())

while number > 0:
    print(number%10)
    # number= int (number/10)
    number //=10
# Out:
# 2
# 3
# 4
# 5
# 0

# %%
t = int(input())

for i in range(t):

    number = int (input())

    while number > 0:
        print(number%10, end=" ")
        number //=10
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t = int(input())
#       3 for i in range(t):
#       5     number = int (input())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
t = int(input())

for i in range(t):

    number = int (input())
    if number ==0:
        print (0)
        continue
    while number > 0:
        print(number%10, end=" ")
        number //=10
    print()
# Out:
# 5 2 0 1
# 0
# 0 0 0 7 7 9 8 6 2 3 2 3 6 5
