# %% [markdown]
# DICTIONARY COMPREHENSION

# %% [markdown]
# expression iterable condition<br>
# key:value<br>
# (iterable can be list, tuple, set)

# %%
square = {x: x**2 for x in range(1, 6)}
print(square)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
square = {x: x**2 for x in range(1, 8)}
print(square)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}
