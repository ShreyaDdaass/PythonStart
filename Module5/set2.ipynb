# %% [markdown]
# SET

# %% [markdown]
# unique element store
# <br>
# mutable<br>
# unordered..no indexing and slicing

# %%
A = {1, 2, 3}
print (type(A), A)
# Out:
# <class 'set'> {1, 2, 3}

# %% [markdown]
# Empty Structures

# %%
B = []
print (type(B), B)

C = ()
print (type(C), C)

D = {}
print (type(D), D)

E = set()
print (type(E), E)
# Out:
# <class 'list'> []
# <class 'tuple'> ()
# <class 'dict'> {}
# <class 'set'> set()

# %%
S = {1, 2, 3, 1, 5, 6, 4, 5,1, 2, 3}
if (3 in S ):
    print ("3 is Present")
else:
    print ("3 is not Present")
print (type(S), S)

for element in S:
    print (element)
# Out:
# 3 is Present
# <class 'set'> {1, 2, 3, 4, 5, 6}
# 1
# 2
# 3
# 4
# 5
# 6
