# %%
phone_number = "123-456-7890"
print(phone_number)
# Out:
# 123-456-7890

# %%
name = "Shreya"
print(name)
# Out:
# Shreya

# %%
age = 25
height = 5.6
name = "Shreya"
is_passed = True 
# can't write true in lowercase because it'a special built-in value in Python: False
print(type(age),type(height),type(name),type(is_passed))
age = 30.5
print(type(age))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# <class 'float'>

# %% [markdown]
# Taking Input in Python

# %%
name = input("What is your name?")
print(name)
# Out:
# 10

# %%
age = input("What is your age?")
print(age , type(age))
# Out:
# 20 <class 'str'>

# %%
age = input("What is your age?")# input function always returns a string
age = int(age)  # convert the string to an integer
print(age , type(age))
# Out:
# 58 <class 'int'>

# %%
height = input("What is your height?")

print(height , type(height))
# Out:
# 10.2 <class 'str'>

# %%
height = float(input("What is your height?"))#str

height = height + 0.4
print(height , type(height))
# Out:
# 20.4 <class 'float'>
