# %%
print("hello world")
# Out:
# hello world

# %%
prompt = "what is your name?"
print (prompt)
print (type (prompt))
# Out:
# what is your name?
# <class 'str'>

# %% [markdown]
# message = "" Tell me something
# how are you?
# Is it raining?
# ""
# print (message)

# %% [markdown]
# message = """ Tell me something
# how are you?
# Is it raining?
# """
# print (message)

# %% [markdown]
# Indencing & Slicing

# %%
string = "hello world"
print (string[0])
# Out:
# h

# %%
first_message = message [0:18]
print (first_message)
# Out:
#  Tell me something

# %%
first_message = message [0:18]  
# 0:18:2 == start:end:word gap
print (first_message)
# Out:
#  Tell me something

# %%
print (first_message[-1])
# Out:
# g

# %% [markdown]
# String Method

# %%
string = "Welcome to Phitron"
# to find something in lowercase/ uppercase

# processed_string = string.lower()
# processed_string = string.upper()   
# processed_string = string.capitalized()....will start capital letter in start   

# print(processed_string)
# length or word cheak 
# print(len(string))
# print ("to" in string) 

#kotheke index er substring suru hoise
# index = processed_string.find("to")
# index = processed_string.rfind("Phitron")

# print(index)

# koibar ache substring
# count = processed_string.count("phitron")
# print(count)

# replace a sub_string
# without new_string it would not work
new_string = string.replace("to","allover")
print(new_string)

# %% [markdown]
# Splitting, Joining, Formatted String

# %%
prompt = "what is Phitron ?"

tokens = prompt.split()

print(tokens)
# Out:
# ['what', 'is', 'Phitron', '?']

# %%
prompt = "what-is-Phitron ?"

tokens = prompt.split()

print(tokens)
# Out:
# ['what-is-Phitron', '?']

# %%
prompt = "what-is-Phitron ?"

tokens = prompt.split("-")

print(tokens)
# Out:
# ['what', 'is', 'Phitron ?']

# %%
prompt = "what is Phitron ?"

tokens = prompt.split()

print(type(tokens))

sentence = "-".join(tokens)

print (type(sentence))
# Out:
# <class 'list'>
# <class 'str'>

# %% [markdown]
# Formatted String

# %%
name =" April"
age = 23
height = 5.036565

print(f"His name is{name.upper()}. He is {age} years old.\nHis height is {height:.4}")
# Out:
# His name is APRIL. He is 23 years old.
# His height is 5.037

# %%
name =" April"
age = 23
height = 5.036565

info = f"His name is{name.upper()}. He is {age} years old.\nHis height is {height:.4}"
print(info)
print(type(info))

model_accuracy = 0.33365656
print (f"the model_accuracy is {model_accuracy:.2}")
print (f"the model_accuracy is {model_accuracy:.2%}")
print (f"the model_accuracy is {model_accuracy+10}")
# Out:
# His name is APRIL. He is 23 years old.
# His height is 5.037
# <class 'str'>
# the model_accuracy is 0.33
# the model_accuracy is 33.37%
# the model_accuracy is 10.33365656

# %% [markdown]
# 3.4 videoooooooo!!!
